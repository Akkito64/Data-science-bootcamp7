# %% [markdown]
# # Final Project - Analyzing Sales Data
#
# **Date**: 30 December 2021
#
# **Author**: Ratchaphon kuntipsombut
#
# **Course**: `Pandas Foundation`

# %%
# import data
import pandas as pd
df = pd.read_csv("sample-store.csv")

# %%
# preview top 5 rows
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2019-152156   11/8/2019  11/11/2019    Second Class    CG-12520
# 1       2  CA-2019-152156   11/8/2019  11/11/2019    Second Class    CG-12520
# 2       3  CA-2019-138688   6/12/2019   6/16/2019    Second Class    DV-13045
# 3       4  US-2018-108966  10/11/2018  10/18/2018  Standard Class    SO-20335
# 4       5  US-2018-108966  10/11/2018  10/18/2018  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# shape of dataframe
df.shape
# Out:
# (9994, 21)

# %%
# see data frame information using .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   object
#  3   Ship Date       9994 non-null   object
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
#  16  Product Name    9994 non-null   object
# ...

# %%
# example of pd.to_datetime() function
pd.to_datetime(df['Order Date'].head(), format='%m/%d/%Y')
# Out:
# 0   2019-11-08
# 1   2019-11-08
# 2   2019-06-12
# 3   2018-10-11
# 4   2018-10-11
# Name: Order Date, dtype: datetime64[ns]

# %%
# TODO - convert order date and ship date to datetime in the original dataframe
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
# Check answer
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
# ...

# %%
# TODO - count nan in postal code column
nan_count = df['Postal Code'].isna().sum()
print("Number of NaN values in the Postal Code column:", nan_count)
# Out:
# Number of NaN values in the Postal Code column: 11

# %%
# TODO - filter rows with missing values
df_filter = df.dropna()

print("Filtered DataFrame:")
df_filter.info()
# Out:
# Filtered DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9983 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9983 non-null   int64
#  1   Order ID        9983 non-null   object
#  2   Order Date      9983 non-null   datetime64[ns]
#  3   Ship Date       9983 non-null   datetime64[ns]
#  4   Ship Mode       9983 non-null   object
#  5   Customer ID     9983 non-null   object
#  6   Customer Name   9983 non-null   object
#  7   Segment         9983 non-null   object
#  8   Country/Region  9983 non-null   object
#  9   City            9983 non-null   object
#  10  State           9983 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9983 non-null   object
#  13  Product ID      9983 non-null   object
#  14  Category        9983 non-null   object
#  15  Sub-Category    9983 non-null   object
# ...

# %%
# TODO - Explore this dataset on your owns, ask your own questions
# Calculate the total sales
total_sales = df['Sales'].sum()

# Calculate the total profit
total_profit = df['Profit'].sum()

# Print the results
print("Total Sales:", total_sales)
print("Total Profit:", total_profit)
# Out:
# Total Sales: 2297200.8603000003
# Total Profit: 286397.0217

# %% [markdown]
# # Data Analysis Part
#  Answer 10 below questions to get credit from this course. Write pandas code to find answers.

# %%
# TODO 01 - how many columns, rows in this dataset
num_rows, num_columns = df.shape

# Print the results
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 9994
# Number of columns: 21

# %%
# TODO 02 - is there any missing values?, if there is, which colunm? how many nan values?
missing_value = df.isna().sum()

# Filter columns with missing values
columns_with_missing_values = missing_value[missing_value > 0]

print(columns_with_missing_values)
# Out:
# Postal Code    11
# dtype: int64

# %%
# TODO 03 - your friend ask for `California` data, filter it and export csv for him

# Filter the dataset for California data
california_data = df.loc[df['State'] == 'California']

# Export the filtered data to a CSV file
california_data.to_csv('california_data.csv', index=False)

# %%
# TODO 04 - your friend ask for all order data in `California` and `Texas` in 2017 (look at Order Date), send him csv file
# Filter the dataset for California and Texas data in 2017
filtered_data = df.loc[(df['State'].isin(['California', 'Texas'])) & (df['Order Date'].dt.year == 2017)]

# Export the filtered data to a CSV file
filtered_data.to_csv('california_texas_2017_data.csv', index=False)

# %%
# TODO 05 - how much total sales, average sales, and standard deviation of sales your company make in 2017

# Filter the dataset for 2017 data
data_2017 = df[df['Order Date'].dt.year == 2017]

# Calculate the total sales
total_sales_2017 = data_2017['Sales'].sum()

# Calculate the average sales
average_sales_2017 = data_2017['Sales'].mean()

# Calculate the standard deviation of sales
std_sales_2017 = data_2017['Sales'].std()

# Print the results
print("Total Sales in 2017:", round(total_sales_2017,3))
print("Average Sales in 2017:", round(average_sales_2017,3))
print("Standard Deviation of Sales in 2017:", round(std_sales_2017,3))
# Out:
# Total Sales in 2017: 484247.498
# Average Sales in 2017: 242.974
# Standard Deviation of Sales in 2017: 754.053

# %%
# TODO 06 - which Segment has the highest profit in 2018

exam06 = df[df['Order Date'].dt.year == 2018].groupby('Segment')['Profit'].max()

display(exam06)
# Out:
# Segment
# Consumer       3177.4750
# Corporate      2302.9671
# Home Office    1906.4850
# Name: Profit, dtype: float64

# %%
# TODO 07 - which top 5 States have the least total sales between 15 April 2019 - 31 December 2019

sales = df[(df['Order Date'] > '2019-04-15') & (df['Order Date'] < '2019-12-31')].groupby('State')['Sales'].sum().sort_values(ascending= True).head()

sales
# Out:
# State
# New Hampshire            49.05
# New Mexico               64.08
# District of Columbia    117.07
# Louisiana               249.80
# South Carolina          502.48
# Name: Sales, dtype: float64

# %%
# TODO 08 - what is the proportion of total sales (%) in West + Central in 2019 e.g. 25% 

# Filter the dataset for 2019 data in the West and Central regions
data_2019_west_central = df[(df['Order Date'].dt.year == 2019) & (df['Region'].isin(['West', 'Central']))]

# Calculate the total sales for West and Central in 2019
sales_west_central_2019 = data_2019_west_central['Sales'].sum()

# Calculate the total sales for the entire dataset in 2019
total_sales_2019 = df[df['Order Date'].dt.year == 2019]['Sales'].sum()

# Calculate the proportion of sales in West and Central in 2019
proportion_sales_west_central_2019 = round((sales_west_central_2019 / total_sales_2019) * 100,2)

# Print the proportion of sales in West and Central in 2019
print("Proportion of total sales (%) in West + Central in 2019:", int(proportion_sales_west_central_2019), "%")
# Out:
# Proportion of total sales (%) in West + Central in 2019: 54 %

# %%
# TODO 09 - find top 10 popular products in terms of number of orders vs. total sales during 2019-2020

df_product = df[(df['Order Date'].dt.year >= 2019) & (df['Order Date'].dt.year <= 2020)].groupby("Product Name")['Product ID'].count().sort_values(ascending = False).head(10)

df_Total_Salse = df[(df['Order Date'].dt.year >= 2019) & (df['Order Date'].dt.year <= 2020)].groupby("Product Name")['Sales'].sum().sort_values(ascending = False).head(10)

print("top 10 popular products in terms of number of orders\n",df_product,"\n")

print("----------------------------------------------------------------------------------\n")

print("top 10 popular products in terms of total sales\n",df_Total_Salse,"\n")
# Out:
# top 10 popular products in terms of number of orders
#  Product Name
# Easy-staple paper                                  27
# Staples                                            24
# Staple envelope                                    22
# Staples in misc. colors                            13
# Staple remover                                     12
# Storex Dura Pro Binders                            12
# Chromcraft Round Conference Tables                 12
# Global Wood Trimmed Manager's Task Chair, Khaki    11
# Avery Non-Stick Binders                            11
# Staple-based wall hangings                         10
# Name: Product ID, dtype: int64
#
# ----------------------------------------------------------------------------------
#
# top 10 popular products in terms of total sales
#  Product Name
# Canon imageCLASS 2200 Advanced Copier                 61599.824
# Hewlett Packard LaserJet 3310 Copier                  16079.732
# ...

# %%
import matplotlib.pyplot as plt
# TODO 10 - plot at least 2 plots, any plot you think interesting :)

# plot 1 : 'Sales * Quantity for Each Ship Mode'

# Calculate the sales multiplied by quantity
df['Total'] = df['Sales'] * df['Quantity']

# Group the data by ship mode and calculate the sum of the 'Total' column
grouped_data = df.groupby('Ship Mode')['Total'].sum().sort_values(ascending=False)

# Plot the data
plt.subplot(1,1,1)
plt.bar(grouped_data.index, grouped_data.values)
plt.xlabel('Ship Mode')
plt.ylabel('Sales * Quantity')
plt.title('Sales * Quantity for Each Ship Mode')
plt.show()


#plot 2 'Sales * Quantity for each Category

# Group the data by category and calculate the sum of the 'Total' column
grouped_data = df.groupby('Category')['Total'].sum()

# Sort the data in descending order and select the top 10 categories
categories = grouped_data.nlargest(10)

# Plot the data
plt.subplot(2,1,1)
plt.bar(categories.index, categories.values)
plt.xlabel('Category')
plt.ylabel('Sales * Quantity')
plt.title('Categories by Sales * Quantity')
plt.xticks(rotation=90)
plt.show()

# %%
import numpy as np
# TODO Bonus - use np.where() to create new column in dataframe to help you answer your own questions

df['My_Question'] = np.where((df['Quantity'] > 2) & (df['Discount'] > 0), True, False)
# How many product that customer bought > 2 and has discount?
print("Total product that customers bought >2 and has discount: ",df.My_Question.sum())

df.head(10)
# Out:
# Total product that customers bought >2 and has discount:  3458
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 1       2  CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 2       3  CA-2019-138688 2019-06-12 2019-06-16    Second Class    DV-13045
# 3       4  US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
# 4       5  US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
# 5       6  CA-2017-115812 2017-06-09 2017-06-14  Standard Class    BH-11710
# 6       7  CA-2017-115812 2017-06-09 2017-06-14  Standard Class    BH-11710
# 7       8  CA-2017-115812 2017-06-09 2017-06-14  Standard Class    BH-11710
# 8       9  CA-2017-115812 2017-06-09 2017-06-14  Standard Class    BH-11710
# 9      10  CA-2017-115812 2017-06-09 2017-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment Country/Region             City  ...  \
# ...
